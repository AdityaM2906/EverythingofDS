# %%
base_url ="http://api.exchangeratesapi.io/v1/latest?access_key=da407bf4456e7aa7d33b709d0cbff532"

# %%
import requests

# %%
response = requests.get(base_url)
response
# Out:
# <Response [200]>

# %% [markdown]
# ## Investigation the response

# %%
response.ok
# Out:
# True

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '{"success":true,"timestamp":1685527024,"base":"EUR","date":"2023-05-31","rates":{"AED":3.919616,"AFN":93.451292,"ALL":109.555196,"AMD":410.992594,"ANG":1.92281,"AOA":603.000983,"ARS":254.901534,"AUD":1.647223,"AWG":1.921065,"AZN":1.853333,"BAM":1.944411,"BBD":2.154122,"BDT":114.46949,"BGN":1.958238,"BHD":0.402328,"BIF":3010.139779,"BMD":1.067258,"BND":1.44204,"BOB":7.372813,"BRL":5.375248,"BSD":1.06692,"BTC":3.9333703e-5,"BTN":88.225217,"BWP":14.695713,"BYN":2.69295,"BYR":20918.266403,"BZD":2.150543,"CAD":1.456205,"CDF":2492.048299,"CHF":0.972005,"CLF":0.03113,"CLP":858.982716,"CNY":7.585543,"COP":4688.466546,"CRC":576.912603,"CUC":1.067258,"CUP":28.28235,"CVE":109.62785,"CZK":23.718725,"DJF":189.96195,"DKK":7.448237,"DOP":58.367291,"DZD":146.080787,"EGP":32.974769,"ERN":16.008877,"ETB":58.252863,"EUR":1,"FJD":2.408159,"FKP":0.860586,"GBP":0.863497,"GEL":2.769539,"GGP":0.860586,"GHS":11.896317,"GIP":0.860586,"GMD":63.555269,"GNF":9172.016719,"GTQ":8.34313,"GYD":225.658198,"HKD":8.36
# ...

# %%
response.content
# Out:
# b'{"success":true,"timestamp":1685527024,"base":"EUR","date":"2023-05-31","rates":{"AED":3.919616,"AFN":93.451292,"ALL":109.555196,"AMD":410.992594,"ANG":1.92281,"AOA":603.000983,"ARS":254.901534,"AUD":1.647223,"AWG":1.921065,"AZN":1.853333,"BAM":1.944411,"BBD":2.154122,"BDT":114.46949,"BGN":1.958238,"BHD":0.402328,"BIF":3010.139779,"BMD":1.067258,"BND":1.44204,"BOB":7.372813,"BRL":5.375248,"BSD":1.06692,"BTC":3.9333703e-5,"BTN":88.225217,"BWP":14.695713,"BYN":2.69295,"BYR":20918.266403,"BZD":2.150543,"CAD":1.456205,"CDF":2492.048299,"CHF":0.972005,"CLF":0.03113,"CLP":858.982716,"CNY":7.585543,"COP":4688.466546,"CRC":576.912603,"CUC":1.067258,"CUP":28.28235,"CVE":109.62785,"CZK":23.718725,"DJF":189.96195,"DKK":7.448237,"DOP":58.367291,"DZD":146.080787,"EGP":32.974769,"ERN":16.008877,"ETB":58.252863,"EUR":1,"FJD":2.408159,"FKP":0.860586,"GBP":0.863497,"GEL":2.769539,"GGP":0.860586,"GHS":11.896317,"GIP":0.860586,"GMD":63.555269,"GNF":9172.016719,"GTQ":8.34313,"GYD":225.658198,"HKD":8.3
# ...

# %%
type(response.content)
# Out:
# bytes

# %%
response.content == response.text
# Out:
# False

# %% [markdown]
# ### Handling the JSON

# %%
response.json()
# Out:
# {'success': True,
#  'timestamp': 1685527024,
#  'base': 'EUR',
#  'date': '2023-05-31',
#  'rates': {'AED': 3.919616,
#   'AFN': 93.451292,
#   'ALL': 109.555196,
#   'AMD': 410.992594,
#   'ANG': 1.92281,
#   'AOA': 603.000983,
#   'ARS': 254.901534,
#   'AUD': 1.647223,
#   'AWG': 1.921065,
#   'AZN': 1.853333,
#   'BAM': 1.944411,
#   'BBD': 2.154122,
#   'BDT': 114.46949,
#   'BGN': 1.958238,
#   'BHD': 0.402328,
#   'BIF': 3010.139779,
#   'BMD': 1.067258,
#   'BND': 1.44204,
#   'BOB': 7.372813,
#   'BRL': 5.375248,
#   'BSD': 1.06692,
#   'BTC': 3.9333703e-05,
#   'BTN': 88.225217,
#   'BWP': 14.695713,
#   'BYN': 2.69295,
#   'BYR': 20918.266403,
#   'BZD': 2.150543,
#   'CAD': 1.456205,
#   'CDF': 2492.048299,
#   'CHF': 0.972005,
#   'CLF': 0.03113,
#   'CLP': 858.982716,
#   'CNY': 7.585543,
#   'COP': 4688.466546,
#   'CRC': 576.912603,
#   'CUC': 1.067258,
#   'CUP': 28.28235,
#   'CVE': 109.62785,
#   'CZK': 23.718725,
#   'DJF': 189.96195,
#   'DKK': 7.448237,
# ...

# %%
type(response.json())
# Out:
# dict

# %%
import json as js

# %%
 js.dumps(response.json(), indent = 10)
# Out:
# '{\n          "success": true,\n          "timestamp": 1685527024,\n          "base": "EUR",\n          "date": "2023-05-31",\n          "rates": {\n                    "AED": 3.919616,\n                    "AFN": 93.451292,\n                    "ALL": 109.555196,\n                    "AMD": 410.992594,\n                    "ANG": 1.92281,\n                    "AOA": 603.000983,\n                    "ARS": 254.901534,\n                    "AUD": 1.647223,\n                    "AWG": 1.921065,\n                    "AZN": 1.853333,\n                    "BAM": 1.944411,\n                    "BBD": 2.154122,\n                    "BDT": 114.46949,\n                    "BGN": 1.958238,\n                    "BHD": 0.402328,\n                    "BIF": 3010.139779,\n                    "BMD": 1.067258,\n                    "BND": 1.44204,\n                    "BOB": 7.372813,\n                    "BRL": 5.375248,\n                    "BSD": 1.06692,\n                    "BTC": 3.9333703e-05,
# ...

# %%
print( js.dumps(response.json(), indent = 4))
# Out:
# {
#     "success": true,
#     "timestamp": 1685527024,
#     "base": "EUR",
#     "date": "2023-05-31",
#     "rates": {
#         "AED": 3.919616,
#         "AFN": 93.451292,
#         "ALL": 109.555196,
#         "AMD": 410.992594,
#         "ANG": 1.92281,
#         "AOA": 603.000983,
#         "ARS": 254.901534,
#         "AUD": 1.647223,
#         "AWG": 1.921065,
#         "AZN": 1.853333,
#         "BAM": 1.944411,
#         "BBD": 2.154122,
#         "BDT": 114.46949,
#         "BGN": 1.958238,
#         "BHD": 0.402328,
#         "BIF": 3010.139779,
#         "BMD": 1.067258,
#         "BND": 1.44204,
#         "BOB": 7.372813,
#         "BRL": 5.375248,
#         "BSD": 1.06692,
#         "BTC": 3.9333703e-05,
#         "BTN": 88.225217,
#         "BWP": 14.695713,
#         "BYN": 2.69295,
#         "BYR": 20918.266403,
#         "BZD": 2.150543,
#         "CAD": 1.456205,
#         "CDF": 2492.048299,
#         "CHF": 0.972005,
#         "CLF": 0.03113,
# ...

# %%
response.json().keys()
# Out:
# dict_keys(['success', 'timestamp', 'base', 'date', 'rates'])

# %% [markdown]
# ### Just a way to make HTTP request without using "requests" liabrary

# %%
import urllib.request

url = base_url
response = urllib.request.urlopen(url)
content = response.read().decode('utf-8')
print(content)
# Out:
# {"success":true,"timestamp":1685527024,"base":"EUR","date":"2023-05-31","rates":{"AED":3.919616,"AFN":93.451292,"ALL":109.555196,"AMD":410.992594,"ANG":1.92281,"AOA":603.000983,"ARS":254.901534,"AUD":1.647223,"AWG":1.921065,"AZN":1.853333,"BAM":1.944411,"BBD":2.154122,"BDT":114.46949,"BGN":1.958238,"BHD":0.402328,"BIF":3010.139779,"BMD":1.067258,"BND":1.44204,"BOB":7.372813,"BRL":5.375248,"BSD":1.06692,"BTC":3.9333703e-5,"BTN":88.225217,"BWP":14.695713,"BYN":2.69295,"BYR":20918.266403,"BZD":2.150543,"CAD":1.456205,"CDF":2492.048299,"CHF":0.972005,"CLF":0.03113,"CLP":858.982716,"CNY":7.585543,"COP":4688.466546,"CRC":576.912603,"CUC":1.067258,"CUP":28.28235,"CVE":109.62785,"CZK":23.718725,"DJF":189.96195,"DKK":7.448237,"DOP":58.367291,"DZD":146.080787,"EGP":32.974769,"ERN":16.008877,"ETB":58.252863,"EUR":1,"FJD":2.408159,"FKP":0.860586,"GBP":0.863497,"GEL":2.769539,"GGP":0.860586,"GHS":11.896317,"GIP":0.860586,"GMD":63.555269,"GNF":9172.016719,"GTQ":8.34313,"GYD":225.658198,"HKD":8.360
# ...

# %% [markdown]
# ## Incorporating parameters in the GET requests

# %%
param_url = base_url + "&symbols=USD,GBP& base = EUR"
param_url
# Out:
# 'http://api.exchangeratesapi.io/v1/latest?access_key=da407bf4456e7aa7d33b709d0cbff532&symbols=USD,GBP& base = EUR'

# %%
response = requests.get(param_url)
response
# Out:
# <Response [200]>

# %%
data = response.json()
data
# Out:
# {'success': True,
#  'timestamp': 1685527024,
#  'base': 'EUR',
#  'date': '2023-05-31',
#  'rates': {'USD': 1.067258, 'GBP': 0.863497}}

# %%
data['base']
# Out:
# 'EUR'

# %%
data['date']
# Out:
# '2023-05-31'

# %%
data['rates']
# Out:
# {'USD': 1.067258, 'GBP': 0.863497}

# %%
param_url = base_url + "&symbols=GBP"+"&"+"base=EUR"
param_url
# Out:
# 'http://api.exchangeratesapi.io/v1/latest?access_key=da407bf4456e7aa7d33b709d0cbff532&symbols=GBP&base=EUR'

# %%
data = requests.get(param_url).json()
data
# Out:
# {'success': True,
#  'timestamp': 1685527024,
#  'base': 'EUR',
#  'date': '2023-05-31',
#  'rates': {'GBP': 0.863497}}

# %%
usr_to_gbp = data['rates']['GBP']
usr_to_gbp
# Out:
# 0.863497

# %%
base_url ="http://api.exchangeratesapi.io/2022-01-26?access_key=da407bf4456e7aa7d33b709d0cbff532"

# %%
historical_url = base_url 
historical_url
# Out:
# 'http://api.exchangeratesapi.io/2022-01-26?access_key=da407bf4456e7aa7d33b709d0cbff532'

# %%
response = requests.get(historical_url)
response
# Out:
# <Response [200]>

# %%
data = response.json()
print(js.dumps(data, indent=4))
# Out:
# {
#     "success": true,
#     "timestamp": 1643241599,
#     "historical": true,
#     "base": "EUR",
#     "date": "2022-01-26",
#     "rates": {
#         "AED": 4.129161,
#         "AFN": 116.069979,
#         "ALL": 120.84669,
#         "AMD": 542.375153,
#         "ANG": 2.017874,
#         "AOA": 594.091398,
#         "ARS": 117.704514,
#         "AUD": 1.57866,
#         "AWG": 2.017874,
#         "AZN": 1.911286,
#         "BAM": 1.949429,
#         "BBD": 2.269847,
#         "BDT": 96.651752,
#         "BGN": 1.955963,
#         "BHD": 0.423864,
#         "BIF": 2264.066093,
#         "BMD": 1.124164,
#         "BND": 1.511437,
#         "BOB": 7.751249,
#         "BRL": 6.107274,
#         "BSD": 1.124209,
#         "BTC": 3.0497335e-05,
#         "BTN": 84.143322,
#         "BWP": 12.929148,
#         "BYN": 2.939748,
#         "BYR": 22033.612429,
#         "BZD": 2.26606,
#         "CAD": 1.423073,
#         "CDF": 2253.948872,
#         "CHF": 1.038807,
# ...

# %%
time_period = base_url
time_period
# Out:
# 'http://api.exchangeratesapi.io/2022-01-26?access_key=da407bf4456e7aa7d33b709d0cbff532'

# %%
time_period = 'http://api.exchangeratesapi.io' + "/v1/timeseries" + "?access_key=da407bf4456e7aa7d33b709d0cbff532" + "&start_at=2017-04-26&end_at=2018-04-26" + "&symbols = GBP"
time_period
# Out:
# 'http://api.exchangeratesapi.io/v1/timeseries?access_key=da407bf4456e7aa7d33b709d0cbff532&start_at=2017-04-26&end_at=2018-04-26&symbols = GBP'

# %%
data = requests.get(time_period).json()
data
# Out:
# {'error': {'code': 'function_access_restricted',
#   'message': 'Access Restricted - Your current Subscription Plan does not support this API Function.'}}

# %%
print(js.dumps(data, indent=4))
# Out:
# {
#     "error": {
#         "code": "function_access_restricted",
#         "message": "Access Restricted - Your current Subscription Plan does not support this API Function."
#     }
# }

# %% [markdown]
# ### Create a simple currency converter

# %%
base_urlb
# Out:
# 'http://api.exchangeratesapi.io/2022-01-26?access_key=da407bf4456e7aa7d33b709d0cbff532'

# %%
base_url = 'http://api.exchangeratesapi.io/v1'

# %%
date = input("Please enter the date (in the format 'yyyy-mm-dd or 'latest')")
base = input("Convert from (currency):")
curr = input("Convert to (currency):")
quan = float(input("How much {} do you want to convert:".format(base)))

url = base_url + "/" + date + "?access_key=a6a83b37e98c89b2b6df4ceab2ff79fd" + "&base=" + base + "&symbols=" + curr
response = requests.get(url)

if (response.ok is False):
    print("\nError {}".format(response.status_code))
    print(response.json()['error'])
    
else:
    data = response.json()
    rate = data['rates'][curr]
    
    result = quan*rate
    
    print("\n{0} {1} is equal to {2} {3}, based upon exchange rates on {4}".format(quan,base,result,curr,data['date']))
# Out:
# Please enter the date (in the format 'yyyy-mm-dd or 'latest')latest
# Convert from (currency):EUR
# Convert to (currency):USD
# How much EUR do you want to convert:200
#
# 200.0 EUR is equal to 213.55659999999997 USD, based upon exchange rates on 2023-05-31

# %% [markdown]
# ### Passing parameters in the request with iTunes search API

# %%
base_site = "http://itunes.apple.com/search"

# %%
url = base_site + "?term=the+beatles&country=us"

requests.get(url)
# Out:
# <Response [200]>

# %%
r = requests.get(base_site, params = {"term": "the beatles", "country":"us"})
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'http://itunes.apple.com/search?term=the+beatles&country=us'

# %% [markdown]
# ### Investigating the output and parameters

# %%
info = r.json()
print(js.dumps(info, indent=4))
# Out:
# {
#     "resultCount": 50,
#     "results": [
#         {
#             "wrapperType": "audiobook",
#             "artistId": 160778930,
#             "collectionId": 1439484338,
#             "artistName": "Bob Spitz",
#             "collectionName": "The Beatles (Abridged)",
#             "collectionCensoredName": "The Beatles (Abridged)",
#             "artistViewUrl": "https://books.apple.com/us/author/bob-spitz/id160778930?uo=4",
#             "collectionViewUrl": "https://books.apple.com/us/audiobook/the-beatles-abridged/id1439484338?uo=4",
#             "artworkUrl60": "https://is3-ssl.mzstatic.com/image/thumb/Music128/v4/69/b8/65/69b86591-ce4b-9bd0-ab71-3808d0ea06dc/9780743552455.jpg/60x60bb.jpg",
#             "artworkUrl100": "https://is3-ssl.mzstatic.com/image/thumb/Music128/v4/69/b8/65/69b86591-ce4b-9bd0-ab71-3808d0ea06dc/9780743552455.jpg/100x100bb.jpg",
#             "collectionPrice": 16.99,
#             "collectionExplicitness": "notExplicit",
# ...

# %%
info.keys()
# Out:
# dict_keys(['resultCount', 'results'])

# %%
print(js.dumps(info['results'][0], indent=4))
# Out:
# {
#     "wrapperType": "audiobook",
#     "artistId": 160778930,
#     "collectionId": 1439484338,
#     "artistName": "Bob Spitz",
#     "collectionName": "The Beatles (Abridged)",
#     "collectionCensoredName": "The Beatles (Abridged)",
#     "artistViewUrl": "https://books.apple.com/us/author/bob-spitz/id160778930?uo=4",
#     "collectionViewUrl": "https://books.apple.com/us/audiobook/the-beatles-abridged/id1439484338?uo=4",
#     "artworkUrl60": "https://is3-ssl.mzstatic.com/image/thumb/Music128/v4/69/b8/65/69b86591-ce4b-9bd0-ab71-3808d0ea06dc/9780743552455.jpg/60x60bb.jpg",
#     "artworkUrl100": "https://is3-ssl.mzstatic.com/image/thumb/Music128/v4/69/b8/65/69b86591-ce4b-9bd0-ab71-3808d0ea06dc/9780743552455.jpg/100x100bb.jpg",
#     "collectionPrice": 16.99,
#     "collectionExplicitness": "notExplicit",
#     "trackCount": 1,
#     "country": "USA",
#     "currency": "USD",
#     "releaseDate": "2005-11-01T08:00:00Z",
#     "primaryGenreName": "Biographies & Memoirs",
# ...

# %%
r = requests.get(base_site, params = {"terms": "the beatles","country":"us","limit":200})
r.ok
# Out:
# True

# %%
r.json()["resultCount"]
# Out:
# 0

# %%
r = requests.get(base_site, params = {"media":"hahaha", "term":"alternative","country":"us"})
r.status_code
# Out:
# 400

# %%
r.json()
# Out:
# {'errorMessage': 'Invalid value(s) for key(s): [mediaType]',
#  'queryParameters': {'output': 'json',
#   'callback': 'A javascript function to handle your search results',
#   'country': 'ISO-2A country code',
#   'limit': 'The number of search results to return',
#   'term': 'A search string',
#   'lang': 'ISO-2A language code'}}
